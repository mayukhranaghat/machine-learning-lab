# %%
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold   
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn import metrics
from sklearn.naive_bayes import GaussianNB
# %matplotlib inline

# %%
df = pd.read_csv("data.csv")
df.drop('id',axis=1,inplace=True)
df.drop('Unnamed: 32',axis=1,inplace=True)
df['diagnosis'] = df['diagnosis'].map({'M':1,'B':0})

# %%
df.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean           ...             radius_worst  texture_worst  \
# ...

# %%
#df.describe()
plt.hist(df['diagnosis'])
plt.title('Diagnosis (M=1 , B=0)')
plt.show()
features_mean=list(df.columns[1:11])
dfM=df[df['diagnosis'] ==1]
dfB=df[df['diagnosis'] ==0]

# %%
plt.rcParams.update({'font.size': 8})
fig, axes = plt.subplots(nrows=5, ncols=2, figsize=(8,10))
axes = axes.ravel()
for idx,ax in enumerate(axes):
    ax.figure
    binwidth= (max(df[features_mean[idx]]) - min(df[features_mean[idx]]))/50
    ax.hist([dfM[features_mean[idx]],dfB[features_mean[idx]]], bins=np.arange(min(df[features_mean[idx]]), max(df[features_mean[idx]]) + binwidth, binwidth) , alpha=0.5,stacked=True, normed = True, label=['M','B'],color=['r','g'])
    ax.legend(loc='upper right')
    ax.set_title(features_mean[idx])
plt.tight_layout()
plt.show()
# Out:
# D:\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# D:\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:52: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
traindf, testdf = train_test_split(df, test_size = 0.25)
def classification_model(model, data, predictors, outcome):
  arr = np.zeros((6,1))
  model.fit(data[predictors],data[outcome])
  predictions = model.predict(data[predictors])
  accuracy = metrics.accuracy_score(predictions,data[outcome])
  cm = metrics.confusion_matrix(predictions,data[outcome])
  print("Accuracy : %s" % "{0:.3%}".format(accuracy))
  kf = KFold(n_splits=5)
  error = []
  arr[0][0] = accuracy
  index = 1
  for train, test in kf.split(data):
    train_predictors = (data[predictors].iloc[train,:])
    train_target = data[outcome].iloc[train]
    model.fit(train_predictors, train_target)
    error.append(model.score(data[predictors].iloc[test,:], data[outcome].iloc[test]))  
    print("Cross-Validation Score : %s" % "{0:.3%}".format(np.mean(error)))
    arr[index][0] = np.mean(error)
    index += 1
  model.fit(data[predictors],data[outcome]) 
  sn.heatmap(cm,annot = True,fmt = 'd')
  return arr

# %%
predictor_var = ['radius_mean','perimeter_mean','area_mean','compactness_mean','concave points_mean']
outcome_var='diagnosis'
model=LogisticRegression()
#res_log = classification_model(model,traindf,predictor_var,outcome_var)
res_log = classification_model(model,df,predictor_var,outcome_var)
# Out:
# Accuracy : 89.279%
# Cross-Validation Score : 78.070%
# Cross-Validation Score : 82.018%
# Cross-Validation Score : 86.550%
# Cross-Validation Score : 87.939%
# Cross-Validation Score : 89.112%

# %%
#predictor_var = ['radius_mean','perimeter_mean','area_mean','compactness_mean','concave points_mean']
predictor_var = features_mean
outcome_var='diagnosis'
model=GaussianNB()
#res_NB = classification_model(model,traindf,predictor_var,outcome_var)
res_NB = classification_model(model,df,predictor_var,outcome_var)
# Out:
# Accuracy : 91.037%
# Cross-Validation Score : 82.456%
# Cross-Validation Score : 86.404%
# Cross-Validation Score : 89.474%
# Cross-Validation Score : 90.351%
# Cross-Validation Score : 90.865%

# %%
predictor_var = features_mean
model = RandomForestClassifier(n_estimators=100,min_samples_split=25, max_depth=7, max_features=2)
classification_model(model, df,predictor_var,outcome_var)
featimp = pd.Series(model.feature_importances_, index=predictor_var).sort_values(ascending=False)
print(featimp)
# Out:
# Accuracy : 96.134%
# Cross-Validation Score : 81.579%
# Cross-Validation Score : 86.842%
# Cross-Validation Score : 90.058%
# Cross-Validation Score : 91.228%
# Cross-Validation Score : 91.921%
# concave points_mean       0.260284
# perimeter_mean            0.153740
# radius_mean               0.152041
# area_mean                 0.147933
# concavity_mean            0.142163
# compactness_mean          0.050335
# texture_mean              0.044655
# smoothness_mean           0.025804
# symmetry_mean             0.015009
# fractal_dimension_mean    0.008036
# dtype: float64

# %%
X = np.arange(6)
plt.figure(figsize = (20,5))
plt.plot(X,res_log,'r',label = "Logistic")
plt.plot(X,res_NB,'b',label = "Naive Bayes")
plt.legend()

# %%
res_log
# Out:
# array([[0.89279438],
#        [0.78070175],
#        [0.82017544],
#        [0.86549708],
#        [0.87938596],
#        [0.89111939]])

# %%
res_NB
# Out:
# array([[0.91036907],
#        [0.8245614 ],
#        [0.86403509],
#        [0.89473684],
#        [0.90350877],
#        [0.90864773]])
